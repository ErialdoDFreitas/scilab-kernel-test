# %% [markdown]
# <a href="https://colab.research.google.com/github/ErialdoDFreitas/scilab-kernel-test/blob/main/scilab_kernel_Jupyter_notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %pip install scilab-kernel

# %%
# %%python -m notebook
# Out:
# Process is interrupted.

# %%
# %%python -m scilab_kernel.check
# Out:
# Scilab kernel v0.10.1
# Metakernel v0.30.2
# Python v3.10.12 (main, Nov 20 2023, 15:14:05) [GCC 11.4.0]
# Python path: /usr/bin/python3
#
# Connecting to Scilab...
# Scilab connection established
# Scilab Executable not found, please add to path or set "SCILAB_EXECUTABLE" environment variable

# %%
# %load teste_controle_elevadores_fuzzy.sci

# %%
# %run teste_controle_elevadores_fuzzy.sci
# Out:
#   File "/content/teste_controle_elevadores_fuzzy.sci", line 1
#     // Carregar o sistema fuzzy
#     ^
# SyntaxError: invalid syntax

# %%
# %%scilab
# Out:
# UsageError: Cell magic `%%scilab` not found.

# %%
# !apt-get install scilab
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   ant ant-optional antlr bwidget default-jre default-jre-headless docbook-xml docbook-xsl
#   fonts-dejavu-core fonts-dejavu-extra fop icc-profiles-free java-wrappers javahelp2 junit junit4
#   libactivation-java libamd2 libantlr-java libaopalliance-java libapache-pom-java libargs4j-java
#   libatinject-jsr330-api-java libatk-wrapper-java libatk-wrapper-java-jni libavalon-framework-java
#   libbatik-java libcamd2 libccolamd2 libcdi-api-java libcholmod3 libcodemodel-java libcolamd2
#   libcommons-cli-java libcommons-codec-java libcommons-compress-java libcommons-io-java
#   libcommons-lang3-java libcommons-logging-java libcommons-parent-java libdom4j-java
#   libdtd-parser-java libecj-java libfastinfoset-java libfftw3-double3 libflexdock-java
#   libfontbox2-java libfontenc1 libfop-java libfreehep-graphics2d-java
# ...

# %%
# %%bash
# echo "exec(\"atomsLoad.sce\")"
# Out:
# exec("atomsLoad.sce")

# %%
# %%bash
# echo "atomsInstall("fuzzy_logic_toolkit");"
# Out:
# atomsInstall(fuzzy_logic_toolkit);

# %%
# !scilab-cli -e "exec('teste_controle_elevadores_fuzzy.sci');"
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-b26630c50c41> in <cell line: 1>()
# ----> 1 get_ipython().system('scilab-cli -e "exec(\'teste_controle_elevadores_fuzzy.sci\');"')
#
# /usr/local/lib/python3.10/dist-packages/google/colab/_shell.py in system(self, *args, **kwargs)
#      97       kwargs.update({'also_return_output': True})
#      98
# ---> 99     output = _system_commands._system_compat(self, *args, **kwargs)  # pylint:disable=protected-access
#     100
#     101     if pip_warn:
#
# /usr/local/lib/python3.10/dist-packages/google/colab/_system_commands.py in _system_compat(shell, cmd, also_return_output)
#     452   # is expected to call this function, thus adding one level of nesting to the
#     453   # stack.
# --> 454   result = _run_command(
#     455       shell.var_expand(cmd, depth=2), clear_streamed_output=False
#     456   )
#
# ...

# %%
# %%writefile load_atoms.sce
# atomsInstall("atoms");
#
# // Carregar o gerenciador de pacotes Atoms
# atomsLoad();
# Out:
# Overwriting load_atoms.sce

# %%
# !scilab-cli -f load_atoms.sce
# Out:
# Scilab branch-6.1 (Apr 14 2022, 22:30:04)
# atomsInstallList: The package "atoms" is not registered.
# Please check on the ATOMS repository that it is available for Scilab 6.1 on Linux.
# If it is, run atomsSystemUpdate() before trying atomsInstall(..) again.
#
# at line    52 of function atomsError       ( /usr/share/scilab/modules/atoms/macros/atoms_internals/atomsError.sci line 66 )
# at line    78 of function atomsInstallList ( /usr/share/scilab/modules/atoms/macros/atoms_internals/atomsInstallList.sci line 117 )
# at line   233 of function atomsInstall     ( /usr/share/scilab/modules/atoms/macros/atomsInstall.sci line 249 )
# at line     1 of executed file /content/load_atoms.sce
#
#
# -->
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-c2ebed045cff> in <cell line: 1>()
# ----> 1 get_ipython().system('scilab-cli -f load_atoms.sce')
#
# ...

# %%
# %%writefile scilab_commands.sce
# exec("atomsLoad.sce");
# atomsInstall("fuzzy_logic_toolkit");
# exec('teste_controle_elevadores_fuzzy.sci');
# Out:
# Writing scilab_commands.sce

# %%
# !scilab-cli -f scilab_commands.sce
# Out:
# Scilab branch-6.1 (Apr 14 2022, 22:30:04)
# at line     1 of executed file /content/scilab_commands.sce
#
# exec: Cannot open file atomsLoad.sce.
#
# -->
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-d92b6e1e27cc> in <cell line: 1>()
# ----> 1 get_ipython().system('scilab-cli -f scilab_commands.sce')
#
# /usr/local/lib/python3.10/dist-packages/google/colab/_shell.py in system(self, *args, **kwargs)
#      97       kwargs.update({'also_return_output': True})
#      98
# ---> 99     output = _system_commands._system_compat(self, *args, **kwargs)  # pylint:disable=protected-access
#     100
#     101     if pip_warn:
#
# /usr/local/lib/python3.10/dist-packages/google/colab/_system_commands.py in _system_compat(shell, cmd, also_return_output)
#     452   # is expected to call this function, thus adding one level of nesting to the
#     453   # stack.
# ...

# %%
# %%writefile install_fuzzy_toolkit.sce
# atomsSystemUpdate()
# atomsInstall("sciFLT");
# Out:
# Overwriting install_fuzzy_toolkit.sce

# %%
# !scilab-cli -f install_fuzzy_toolkit.sce
# Out:
# Scilab branch-6.1 (Apr 14 2022, 22:30:04)
# Scanning repository http://atoms.scilab.org/6.1 ... Done
#
#
# 5
#  ans  =
#
#    12345.
#
# --> 2
#  ans  =
#
#    2.
#
# --> 3
#  ans  =
#
#    3.
#
# )
#
# Undefined variable: %pir
#
# )
#  ans  =
#
#    1.
#
# )
#
# Undefined variable: sciFLT
#
# ;
#
# i
#
# Undefined variable: atomsGui
#
# )
#  ans  =
#
#     []
#
# )
# Scanning repository http://atoms.scilab.org/6.1 ... Done
#
#
# )
#  ans  =
#
#     []
#
# ;
#
# Undefined variable: sciFLTdemo
#
# -->
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-2a4435601bde> in <cell line: 1>()
# ----> 1 get_ipython().system('scilab-cli -f install_fuzzy_toolkit.sce')
#
# /usr/local/lib/python3.10/dist-packages/google/colab/_shell.py in system(self, *args, **kwargs)
#      97       kwargs.update({'also_return_output': True})
#      98
# ...

# %%
# !apt-get install libf2c2
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following NEW packages will be installed:
#   libf2c2
# 0 upgraded, 1 newly installed, 0 to remove and 45 not upgraded.
# Need to get 72.5 kB of archives.
# After this operation, 246 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libf2c2 amd64 20140711-1 [72.5 kB]
# Fetched 72.5 kB in 0s (368 kB/s)
# Selecting previously unselected package libf2c2:amd64.
# (Reading database ... 136567 files and directories currently installed.)
# Preparing to unpack .../libf2c2_20140711-1_amd64.deb ...
# Unpacking libf2c2:amd64 (20140711-1) ...
# Setting up libf2c2:amd64 (20140711-1) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.4) ...
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# ...

# %%
# !scilab-cli -nb -f install_fuzzy_toolkit.sce
# Out:
# Start Fuzzy Toolbox 0.5
# 	Load macros
# 	Load shared library
# 	Load gateways
# 	Load palette
# atomsLoad: An error occurred while loading 'sciFLT-0.5':
# 	exec: error on line #92: "Scilab 'xcosPalLoad' function disabled in -nogui or -nwni mode."
# Scanning repository http://atoms.scilab.org/6.1 ... Done
#
#
# -->
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-274267d42c2b> in <cell line: 1>()
# ----> 1 get_ipython().system('scilab-cli -nb -f install_fuzzy_toolkit.sce')
#
# /usr/local/lib/python3.10/dist-packages/google/colab/_shell.py in system(self, *args, **kwargs)
#      97       kwargs.update({'also_return_output': True})
#      98
# ---> 99     output = _system_commands._system_compat(self, *args, **kwargs)  # pylint:disable=protected-access
#     100
#     101     if pip_warn:
#
# ...

# %%
# !scilab-cli -nogui -nwni -nb -f install_fuzzy_toolkit.sce
# Out:
# Start Fuzzy Toolbox 0.5
# 	Load macros
# 	Load shared library
# 	Load gateways
# 	Load palette
# atomsLoad: An error occurred while loading 'sciFLT-0.5':
# 	exec: error on line #92: "Scilab 'xcosPalLoad' function disabled in -nogui or -nwni mode."
# Scanning repository http://atoms.scilab.org/6.1 ... Done
#
#
# --> f
#
# Undefined variable: f
#
# -->
